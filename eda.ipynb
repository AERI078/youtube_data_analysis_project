# %% [markdown]
# # Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('36days_youtube_videos.xlsx')

df.head()
# Out:
#             id region_code          publish_date                channel_id  \
# 0  XhW3i2f54BQ          IN  2025-02-24T05:37:32Z  UC-seBZmnGCMWm9aCHL2WcNQ
# 1  W8x6Dwyj0-A          IN  2025-02-22T11:30:08Z  UCq-Fj5jknLsUf-MWSy4_brA
# 2  dbWfo4NAx8M          IN  2025-02-23T17:12:10Z  UCeWqACGRU5gT0BXeFhrixWA
# 3  DQnZhK6Y27g          IN  2025-02-23T06:11:52Z  UCebC4x5l2-PQxg46Ucv9CsA
# 4  UTaWdNZkGcM          IN  2025-02-23T17:21:39Z  UC9D7QzaNDP11e4jI4ygU5Xg
#
#          channel_name                                              title  \
# 0  Wall Poster Cinema  HIT 3 Teaser : Sarkaar's Laathi | Nani | Saile...
# 1            T-Series  MANIAC (Official Video): YO YO HONEY SINGH | E...
# 2       Shoaib Akhtar  I am Not DisappointedÂ atÂ All | #PAKVIND | Sh...
# 3           Crazy XYZ  Crazy Secret Room Making Challenges Part-3 | à...
# 4            NewsBook  IND vs PAK: India à¤•à¥€ Pakistan à¤ªà¤° Virat...
#
#    category_id  duration  caption     views    likes  comment_count
# 0            1   PT1M45S     True  16695651   323858           6688
# 1           10   PT2M58S    False  25780803  1588648         115750
# 2           17   PT3M53S    False   2064436    83781           5386
# 3           28  PT29M42S    False   4442627   300654          47471
# 4           17  PT11M48S    False   1374247    59617           3526

# %%
pd.set_option("display.float_format", "{:,.2f}".format)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1788 non-null   object
#  1   region_code    1800 non-null   object
#  2   publish_date   1800 non-null   object
#  3   channel_id     1800 non-null   object
#  4   channel_name   1800 non-null   object
#  5   title          1800 non-null   object
#  6   category_id    1800 non-null   int64
#  7   duration       1800 non-null   object
#  8   caption        1800 non-null   bool
#  9   views          1800 non-null   int64
#  10  likes          1800 non-null   int64
#  11  comment_count  1800 non-null   int64
# dtypes: bool(1), int64(4), object(7)
# memory usage: 156.6+ KB

# %%
df.describe()
# Out:
#        category_id         views        likes  comment_count
# count     1,800.00      1,800.00     1,800.00       1,800.00
# mean         18.09  2,601,915.56   108,559.56       7,245.53
# std           6.36  5,123,641.46   206,360.40      14,909.21
# min           1.00     20,125.00         0.00           0.00
# 25%          17.00    401,314.25    13,287.25         845.00
# 50%          20.00    930,178.50    38,145.50       2,413.50
# 75%          24.00  2,665,877.75   107,131.75       6,508.75
# max          28.00 56,602,682.00 2,328,540.00     153,045.00

# %% [markdown]
# # Cleaning Data

# %% [markdown]
# ## 1 Null Values

# %%
df[df['id'].isnull()]
# Out:
#        id region_code          publish_date                channel_id  \
# 171   NaN          BR  2025-02-27T14:00:06Z  UCuo1V_VlMUOTjy89D1FDVDw
# 232   NaN          ID  2025-02-28T09:06:47Z  UC5BMQOsAB8hKUyHu9KI6yig
# 475   NaN          BR  2025-03-06T21:05:06Z  UCYC7HG92sGQjkcMrs8F4wBA
# 624   NaN          BR  2025-03-09T23:08:39Z  UC_oToDrJ6uca7d1dFVBmLtg
# 964   NaN          US  2025-03-17T19:00:33Z  UC0biFgrMdkv1hFAFLVePODQ
# 1306  NaN          IN  2025-03-24T12:35:01Z  UCw5N06QIrXBg92OfOVpvWkg
# 1397  NaN          MX  2025-03-26T02:32:56Z  UC8EdTmyUaFIfZvVttJ9lgIA
# 1448  NaN          MX  2025-03-26T02:32:56Z  UC8EdTmyUaFIfZvVttJ9lgIA
# 1490  NaN          MX  2025-03-28T00:00:06Z  UCncmmq2xV1002xNnx9_rDhw
# 1543  NaN          MX  2025-03-28T00:00:06Z  UCncmmq2xV1002xNnx9_rDhw
# 1612  NaN          US  2025-03-30T15:00:01Z  UCbaGn5VkOVlcRgIWAHcrJKA
# 1666  NaN          US  2025-03-30T15:00:01Z  UCbaGn5VkOVlcRgIWAHcrJKA
#
#                                    channel_name  \
# 171   O Canal Oficial da PokÃ©mon em PortuguÃªs
# 232                                KBS WORLD TV
# 475                                  MUSSA GAME
# 624                                  Canal GOAT
# 964                               Trixie Mattel
# 1306                                 We Are One
# 1397                               ChilevisiÃ³n
# 1448                               ChilevisiÃ³n
# 1490                                  MoratVEVO
# 1543                                  MoratVEVO
# 1612                                        Cut
# 1666                                        Cut
#
#                                                   title  category_id  \
# 171             [Brasil] PokÃ©mon Presents | 27.02.2025           20
# 232   [HOT DEBUT] The Chase - Hearts2Hearts ãƒãƒ¼ãƒ...           24
# 475                  W SUPREMO!! ELE VOLTOU MAIS FORTE!           24
# 624   CEARÃ X MARACANÃƒ | CAMPEONATO CEARENSE | AO ...           17
# 964                     Who Is She?! with Caleb Hearon!           24
# 1306           Lala ka Birthday | Sukki Dc | We Are One           23
# 1397  CHILE 0-0 ECUADORðŸ† Clasificatorias Mundial ...           24
# 1448  CHILE 0-0 ECUADORðŸ† Clasificatorias Mundial ...           24
# 1490      Morat, Camilo - Me Toca A MÃ­ (Video Oficial)           10
# 1543      Morat, Camilo - Me Toca A MÃ­ (Video Oficial)           10
# 1612  Kalogeras Sisters BLIND DATE on The Button! | Cut           24
# 1666  Kalogeras Sisters BLIND DATE on The Button! | Cut           24
#
#         duration  caption    views   likes  comment_count
# 171     PT19M16S    False    35316       0            557
# 232      PT3M25S    False   751676   68072           3414
# 475     PT11M56S    False   146359    7745           4602
# 624   PT3H23M27S    False   561147   21580              6
# 964     PT32M33S    False   549822   41760           2526
# 1306    PT17M48S    False   298187   17117            810
# 1397    PT18M45S    False   312493    1892            961
# 1448    PT18M45S    False   449649    2351           1150
# 1490     PT3M29S     True   608757  102091           5253
# 1543     PT3M29S     True  1171528  123869           5707
# 1612    PT24M25S    False  1754708   80147           2582
# 1666    PT24M25S    False  2591740  103388           3692

# %%
df.at[171, 'id'] = '-n-sxzh_mPk'
df.at[232, 'id'] = '-NYn3BkplZc'
df.at[475, 'id'] = '-WJZvt32838'
df.at[624, 'id'] = 'RKdfhv7ODCM'
df.at[964, 'id'] = '-oSXSqqgZVQ'
df.at[1306, 'id'] = '-ZdfyqKywsQ'
df.at[1397, 'id'] = '-a7f5tggqrA'
df.at[1448, 'id'] = '-a7f5tggqrA'
df.at[1490, 'id'] = '-vOgEO13FYA'
df.at[1543, 'id'] = '-vOgEO13FYA'
df.at[1612, 'id'] = '-u_2wzTaqxE'
df.at[1666, 'id'] = '-u_2wzTaqxE'

# %%
df.id.isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 2 Feature Engineering

# %%
df = df.rename(columns={'publish_date' : 'publish_date_time'}) # renaming appropriately

# %%
# splitting date and time into two columns
df[['publish_date', 'publish_time']] = df['publish_date_time'].str.split('T', expand=True)
df['publish_time'] = df['publish_time'].str.rstrip('Z')

df.head()
# Out:
#             id region_code     publish_date_time                channel_id  \
# 0  XhW3i2f54BQ          IN  2025-02-24T05:37:32Z  UC-seBZmnGCMWm9aCHL2WcNQ
# 1  W8x6Dwyj0-A          IN  2025-02-22T11:30:08Z  UCq-Fj5jknLsUf-MWSy4_brA
# 2  dbWfo4NAx8M          IN  2025-02-23T17:12:10Z  UCeWqACGRU5gT0BXeFhrixWA
# 3  DQnZhK6Y27g          IN  2025-02-23T06:11:52Z  UCebC4x5l2-PQxg46Ucv9CsA
# 4  UTaWdNZkGcM          IN  2025-02-23T17:21:39Z  UC9D7QzaNDP11e4jI4ygU5Xg
#
#          channel_name                                              title  \
# 0  Wall Poster Cinema  HIT 3 Teaser : Sarkaar's Laathi | Nani | Saile...
# 1            T-Series  MANIAC (Official Video): YO YO HONEY SINGH | E...
# 2       Shoaib Akhtar  I am Not DisappointedÂ atÂ All | #PAKVIND | Sh...
# 3           Crazy XYZ  Crazy Secret Room Making Challenges Part-3 | à...
# 4            NewsBook  IND vs PAK: India à¤•à¥€ Pakistan à¤ªà¤° Virat...
#
#    category_id  duration  caption     views    likes  comment_count  \
# 0            1   PT1M45S     True  16695651   323858           6688
# 1           10   PT2M58S    False  25780803  1588648         115750
# 2           17   PT3M53S    False   2064436    83781           5386
# 3           28  PT29M42S    False   4442627   300654          47471
# 4           17  PT11M48S    False   1374247    59617           3526
#
#   publish_date publish_time
# 0   2025-02-24     05:37:32
# 1   2025-02-22     11:30:08
# 2   2025-02-23     17:12:10
# 3   2025-02-23     06:11:52
# 4   2025-02-23     17:21:39

# %%
# convert to appropriate data types
df['publish_date_time'] = pd.to_datetime(df['publish_date_time'], utc=True, errors='coerce') 

df['duration_in_min'] = pd.to_timedelta(df['duration'], errors='coerce').dt.total_seconds() #duration in seconds
df['duration_in_min'] = (df['duration_in_min']/60.00).round(2) #duration in minutes

df.dtypes
# Out:
# id                                object
# region_code                       object
# publish_date_time    datetime64[ns, UTC]
# channel_id                        object
# channel_name                      object
# title                             object
# category_id                        int64
# duration                          object
# caption                             bool
# views                              int64
# likes                              int64
# comment_count                      int64
# publish_date                      object
# publish_time                      object
# duration_in_min                  float64
# dtype: object

# %%
categories = {'1': 'Film & Animation', '2': 'Autos & Vehicles', '10': 'Music', '15': 'Pets & Animals', '17': 'Sports', '18': 'Short Movies', '19': 'Travel & Events', '20': 'Gaming', '21': 'Videoblogging', '22': 'People & Blogs', '23': 'Comedy', '24': 'Entertainment', '25': 'News & Politics', '26': 'Howto & Style', '27': 'Education', '28': 'Science & Technology', '30': 'Movies', '31': 'Anime/Animation', '32': 'Action/Adventure', '33': 'Classics', '34': 'Comedy', '35': 'Documentary', '36': 'Drama', '37': 'Family', '38': 'Foreign', '39': 'Horror', '40': 'Sci-Fi/Fantasy', '41': 'Thriller', '42': 'Shorts', '43': 'Shows', '44': 'Trailers'}

# %%
df['category'] = df['category_id'].apply(lambda x: categories[str(x)] if str(x) in categories.keys() else 'NaN')

df.head()
# Out:
#             id region_code         publish_date_time  \
# 0  XhW3i2f54BQ          IN 2025-02-24 05:37:32+00:00
# 1  W8x6Dwyj0-A          IN 2025-02-22 11:30:08+00:00
# 2  dbWfo4NAx8M          IN 2025-02-23 17:12:10+00:00
# 3  DQnZhK6Y27g          IN 2025-02-23 06:11:52+00:00
# 4  UTaWdNZkGcM          IN 2025-02-23 17:21:39+00:00
#
#                  channel_id        channel_name  \
# 0  UC-seBZmnGCMWm9aCHL2WcNQ  Wall Poster Cinema
# 1  UCq-Fj5jknLsUf-MWSy4_brA            T-Series
# 2  UCeWqACGRU5gT0BXeFhrixWA       Shoaib Akhtar
# 3  UCebC4x5l2-PQxg46Ucv9CsA           Crazy XYZ
# 4  UC9D7QzaNDP11e4jI4ygU5Xg            NewsBook
#
#                                                title  category_id  duration  \
# 0  HIT 3 Teaser : Sarkaar's Laathi | Nani | Saile...            1   PT1M45S
# 1  MANIAC (Official Video): YO YO HONEY SINGH | E...           10   PT2M58S
# 2  I am Not DisappointedÂ atÂ All | #PAKVIND | Sh...           17   PT3M53S
# 3  Crazy Secret Room Making Challenges Part-3 | à...           28  PT29M42S
# 4  IND vs PAK: India à¤•à¥€ Pakistan à¤ªà¤° Virat...           17  PT11M48S
#
#    caption     views    likes  comment_count publish_date publish_time  \
# 0     True  16695651   323858           6688   2025-02-24     05:37:32
# 1    False  25780803  1588648         115750   2025-02-22     11:30:08
# 2    False   2064436    83781           5386   2025-02-23     17:12:10
# 3    False   4442627   300654          47471   2025-02-23     06:11:52
# 4    False   1374247    59617           3526   2025-02-23     17:21:39
#
#    duration_in_min              category
# 0             1.75      Film & Animation
# 1             2.97                 Music
# 2             3.88                Sports
# 3            29.70  Science & Technology
# 4            11.80                Sports

# %%
# checking for missing categories
df[df['category'] == 'Nan']
# Out:
# Empty DataFrame
# Columns: [id, region_code, publish_date_time, channel_id, channel_name, title, category_id, duration, caption, views, likes, comment_count, publish_date, publish_time, duration_in_min, category]
# Index: []

# %% [markdown]
# # Daily Snapshot Analysis

# %% [markdown]
# - creating a column to know when data was collected

# %%
df['group'] = (df.index // 50)
df['collected_date'] = df.groupby('group')['publish_date_time'].transform('max')
df['collected_date'] = df['collected_date'].dt.normalize() # time set to 12am keeping dates same

# %%
df[['collected_date', 'group', 'region_code' ]]
# Out:
#                 collected_date  group region_code
# 0    2025-02-24 00:00:00+00:00      0          IN
# 1    2025-02-24 00:00:00+00:00      0          IN
# 2    2025-02-24 00:00:00+00:00      0          IN
# 3    2025-02-24 00:00:00+00:00      0          IN
# 4    2025-02-24 00:00:00+00:00      0          IN
# ...                        ...    ...         ...
# 1795 2025-04-03 00:00:00+00:00     35          MX
# 1796 2025-04-03 00:00:00+00:00     35          MX
# 1797 2025-04-03 00:00:00+00:00     35          MX
# 1798 2025-04-03 00:00:00+00:00     35          MX
# 1799 2025-04-03 00:00:00+00:00     35          MX
#
# [1800 rows x 3 columns]

# %%
df = df.drop(columns='group')

# %%
df['collected_date'].unique()
# Out:
# <DatetimeArray>
# ['2025-02-24 00:00:00+00:00', '2025-02-25 00:00:00+00:00',
#  '2025-02-26 00:00:00+00:00', '2025-02-27 00:00:00+00:00',
#  '2025-03-01 00:00:00+00:00', '2025-03-02 00:00:00+00:00',
#  '2025-03-04 00:00:00+00:00', '2025-03-05 00:00:00+00:00',
#  '2025-03-06 00:00:00+00:00', '2025-03-07 00:00:00+00:00',
#  '2025-03-08 00:00:00+00:00', '2025-03-09 00:00:00+00:00',
#  '2025-03-10 00:00:00+00:00', '2025-03-11 00:00:00+00:00',
#  '2025-03-12 00:00:00+00:00', '2025-03-14 00:00:00+00:00',
#  '2025-03-15 00:00:00+00:00', '2025-03-16 00:00:00+00:00',
#  '2025-03-17 00:00:00+00:00', '2025-03-18 00:00:00+00:00',
#  '2025-03-19 00:00:00+00:00', '2025-03-20 00:00:00+00:00',
#  '2025-03-21 00:00:00+00:00', '2025-03-22 00:00:00+00:00',
#  '2025-03-23 00:00:00+00:00', '2025-03-24 00:00:00+00:00',
#  '2025-03-25 00:00:00+00:00', '2025-03-26 00:00:00+00:00',
#  '2025-03-27 00:00:00+00:00', '2025-03-28 00:00:00+00:00',
#  '2025-03-29 00:00:00+00:00', '2025-03-30 00:00:00+00:00',
#  '2025-03-31 00:00:00+00:00', '2025-04-01 00:00:00+00:00',
#  '2025-04-02 00:00:00+00:00', '2025-04-03 00:00:00+00:00']
# Length: 36, dtype: datetime64[ns, UTC]

# %% [markdown]
# - getting insights for each day

# %%
# Mean views / likes / comments / duration for each date and region
df['views_per_day'] = df.groupby(['collected_date', 'region_code'])['views'].transform('mean')
df['likes_per_day'] = df.groupby(['collected_date', 'region_code'])['likes'].transform('mean')
df['comment_count_per_day'] = df.groupby(['collected_date', 'region_code'])['comment_count'].transform('mean')
df['duration_in_min_per_day'] = df.groupby(['collected_date', 'region_code'])['duration_in_min'].transform('mean')

# %%
for col in ['views_per_day', 'likes_per_day', 'comment_count_per_day', 'duration_in_min_per_day']:
    plt.figure(figsize=(12, 6))
    sns.lineplot(
        data=df, 
        x='collected_date', 
        y=col, 
        hue='region_code', 
        marker='o'
    )

    plt.title(col.replace('_per_day', ' ').replace('_', ' ').title() + 'per Day by Country')
    plt.xlabel('collected_date')
    plt.ylabel(col.replace('_per_day', ''))
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
# getting most famous categories per day per region
df_unique = df.drop_duplicates(subset='id', keep='first')
df_unique.head()
# Out:
#             id region_code         publish_date_time  \
# 0  XhW3i2f54BQ          IN 2025-02-24 05:37:32+00:00
# 1  W8x6Dwyj0-A          IN 2025-02-22 11:30:08+00:00
# 2  dbWfo4NAx8M          IN 2025-02-23 17:12:10+00:00
# 3  DQnZhK6Y27g          IN 2025-02-23 06:11:52+00:00
# 4  UTaWdNZkGcM          IN 2025-02-23 17:21:39+00:00
#
#                  channel_id        channel_name  \
# 0  UC-seBZmnGCMWm9aCHL2WcNQ  Wall Poster Cinema
# 1  UCq-Fj5jknLsUf-MWSy4_brA            T-Series
# 2  UCeWqACGRU5gT0BXeFhrixWA       Shoaib Akhtar
# 3  UCebC4x5l2-PQxg46Ucv9CsA           Crazy XYZ
# 4  UC9D7QzaNDP11e4jI4ygU5Xg            NewsBook
#
#                                                title  category_id  duration  \
# 0  HIT 3 Teaser : Sarkaar's Laathi | Nani | Saile...            1   PT1M45S
# 1  MANIAC (Official Video): YO YO HONEY SINGH | E...           10   PT2M58S
# 2  I am Not DisappointedÂ atÂ All | #PAKVIND | Sh...           17   PT3M53S
# 3  Crazy Secret Room Making Challenges Part-3 | à...           28  PT29M42S
# 4  IND vs PAK: India à¤•à¥€ Pakistan à¤ªà¤° Virat...           17  PT11M48S
#
#    caption     views  ...  comment_count  publish_date publish_time  \
# 0     True  16695651  ...           6688    2025-02-24     05:37:32
# 1    False  25780803  ...         115750    2025-02-22     11:30:08
# 2    False   2064436  ...           5386    2025-02-23     17:12:10
# 3    False   4442627  ...          47471    2025-02-23     06:11:52
# 4    False   1374247  ...           3526    2025-02-23     17:21:39
#
#   duration_in_min              category            collected_date  \
# 0            1.75      Film & Animation 2025-02-24 00:00:00+00:00
# 1            2.97                 Music 2025-02-24 00:00:00+00:00
# 2            3.88                Sports 2025-02-24 00:00:00+00:00
# 3           29.70  Science & Technology 2025-02-24 00:00:00+00:00
# 4           11.80                Sports 2025-02-24 00:00:00+00:00
#
#   views_per_day  likes_per_day  comment_count_per_day  duration_in_min_per_day
# 0  5,551,852.40     258,084.60              19,007.80                    12.70
# 1  5,551,852.40     258,084.60              19,007.80                    12.70
# 2  5,551,852.40     258,084.60              19,007.80                    12.70
# 3  5,551,852.40     258,084.60              19,007.80                    12.70
# 4  5,551,852.40     258,084.60              19,007.80                    12.70
#
# [5 rows x 21 columns]

# %%
sns.countplot(data=df_unique, x='category', hue='region_code')
plt.xticks(rotation=90)
plt.title('Most occuring categories')
# Out:
# Text(0.5, 1.0, 'Most occuring categories')

# %%
sns.countplot(data=df, x='category', hue='region_code')
plt.xticks(rotation=90)
plt.title('Most occuring categories')
# Out:
# Text(0.5, 1.0, 'Most occuring categories')
